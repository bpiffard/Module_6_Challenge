# %%
# Importing necessary dependencies

import pandas as pd

import requests

import numpy as np

import matplotlib.pyplot as plt

from citipy import citipy

import time

from datetime import datetime

from scipy.stats import linregress

# %%
# Creating a random set of latitude and longitude combinations, and saving to temporary memory
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Saving the lat and lng pairs as a list
coordinates = list(lat_lngs)

# %%
# Importing API key, and setting up url to get weather data
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Creating a list of cities closest to coordinates
# First creating a list to hold the cities
cities = []

# Identify the nearest city to coordinate pairs using a for loop
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate [1]).city_name
    
    # Ensuring only unique cities added
    if city not in cities:
        cities.append(city)
        
# Printing city count
len(cities)
# Out:
# 744

# %%
# Creating empty list to hold weather data
city_data = []

# Print the beginning of the logging
print("Beginning the Data Retrieval     ")
print("---------------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through cities in th list 
for i, city in enumerate(cities):
    
    # Grouping cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create the endpoint url for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URl, record, set numbersm adn the city
    print(f"Processing record {record_count} of Set {set_count} | {city}")\
    
    # Ad 1 to the record count
    record_count += 1
    
    # Run an APi request fort each of the cities
    try: 
        # Parse the JSON and retrieve the data
        city_weather = requests.get(city_url).json()

        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Add all of this data to the city_data list
        city_data.append({
            "City": city.title(),
            "Country": city_country,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Current Description": city_description
        })
    # If an error occurs, skip that city
    except:
        print(f"City not found, skipping... {city}")
        continue
    
# Indicate that data laoding is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning the Data Retrieval
# ---------------------------------
# Processing record 1 of Set 1 | ushuaia
# Processing record 2 of Set 1 | namatanai
# Processing record 3 of Set 1 | saskylakh
# Processing record 4 of Set 1 | khatanga
# Processing record 5 of Set 1 | tisovec
# Processing record 6 of Set 1 | airai
# Processing record 7 of Set 1 | santa luzia
# Processing record 8 of Set 1 | cabo san lucas
# Processing record 9 of Set 1 | iracoubo
# Processing record 10 of Set 1 | kaitangata
# Processing record 11 of Set 1 | ongandjera
# Processing record 12 of Set 1 | aykhal
# Processing record 13 of Set 1 | puerto ayora
# Processing record 14 of Set 1 | rikitea
# Processing record 15 of Set 1 | avarua
# Processing record 16 of Set 1 | hobart
# Processing record 17 of Set 1 | ottawa
# Processing record 18 of Set 1 | surt
# Processing record 19 of Set 1 | neiafu
# Processing record 20 of Set 1 | narsaq
# Processing record 21 of Set 1 | atuona
# Processing record 22 of Set 1 | kavieng
# Processing record 23 of Set 1 | bluff
# Processing record 24 of Set 1 | ahipara
# Processing record 25 of Set 1 | chokurdakh
# Processing record 26 of Set 1 | damnoen saduak
# Processing record 27 of Set 1 | muros
# Processing record 28 of Set 1 | barentsburg
# City not found, skipping... barentsburg
# Processing record 29 of Set 1 | dubenskiy
# City not found, skipping... dubenskiy
# Processing record 30 of Set 1 | aktash
# Processing record 31 of Set 1 | east london
# Processing record 32 of Set 1 | yellowknife
# Processing record 33 of Set 1 | port elizabeth
# Processing record 34 of Set 1 | polyarnyy
# Processing record 35 of Set 1 | victoria
# Processing record 36 of Set 1 | fairbanks
# Processing record 37 of Set 1 | hithadhoo
# Processing record 38 of Set 1 | egvekinot
# Processing record 39 of Set 1 | rawson
# Processing record 40 of Set 1 | tura
# Processing record 41 of Set 1 | punta arenas
# Processing record 42 of Set 1 | raudeberg
# Processing record 43 of Set 1 | praia
# Processing record 44 of Set 1 | mahebourg
# Processing record 45 of Set 1 | nishihara
# Processing record 46 of Set 1 | lang suan
# Processing record 47 of Set 1 | geraldton
# Processing record 48 of Set 1 | agirish
# Processing record 49 of Set 1 | mar del plata
# Processing record 50 of Set 1 | richards bay
# Processing record 1 of Set 2 | la ronge
# Processing record 2 of Set 2 | waipawa
# Processing record 3 of Set 2 | ancud
# Processing record 4 of Set 2 | rocha
# Processing record 5 of Set 2 | new norfolk
# Processing record 6 of Set 2 | mogadishu
# Processing record 7 of Set 2 | calvinia
# Processing record 8 of Set 2 | dikson
# Processing record 9 of Set 2 | jamestown
# Processing record 10 of Set 2 | inirida
# Processing record 11 of Set 2 | hualmay
# Processing record 12 of Set 2 | grand river south east
# City not found, skipping... grand river south east
# Processing record 13 of Set 2 | bambous virieux
# Processing record 14 of Set 2 | bonthe
# Processing record 15 of Set 2 | saint-augustin
# Processing record 16 of Set 2 | roma
# Processing record 17 of Set 2 | hilo
# Processing record 18 of Set 2 | coihaique
# Processing record 19 of Set 2 | louga
# Processing record 20 of Set 2 | albany
# Processing record 21 of Set 2 | gondanglegi
# Processing record 22 of Set 2 | makakilo city
# Processing record 23 of Set 2 | kodiak
# Processing record 24 of Set 2 | simoes
# Processing record 25 of Set 2 | iqaluit
# Processing record 26 of Set 2 | tupik
# Processing record 27 of Set 2 | hargeysa
# Processing record 28 of Set 2 | namanga
# Processing record 29 of Set 2 | fatehabad
# Processing record 30 of Set 2 | bredasdorp
# Processing record 31 of Set 2 | arrecife
# Processing record 32 of Set 2 | exeter
# Processing record 33 of Set 2 | namibe
# Processing record 34 of Set 2 | vaitupu
# City not found, skipping... vaitupu
# Processing record 35 of Set 2 | pizhma
# Processing record 36 of Set 2 | attawapiskat
# City not found, skipping... attawapiskat
# Processing record 37 of Set 2 | tasiilaq
# Processing record 38 of Set 2 | andenes
# Processing record 39 of Set 2 | luganville
# Processing record 40 of Set 2 | butaritari
# Processing record 41 of Set 2 | qaanaaq
# Processing record 42 of Set 2 | vaini
# Processing record 43 of Set 2 | katsuura
# Processing record 44 of Set 2 | kadoshkino
# Processing record 45 of Set 2 | norman wells
# Processing record 46 of Set 2 | bethel
# Processing record 47 of Set 2 | mandan
# Processing record 48 of Set 2 | fort myers beach
# Processing record 49 of Set 2 | samusu
# City not found, skipping... samusu
# Processing record 50 of Set 2 | jumla
# Processing record 1 of Set 3 | kulhudhuffushi
# Processing record 2 of Set 3 | ozinki
# Processing record 3 of Set 3 | roald
# Processing record 4 of Set 3 | broken hill
# Processing record 5 of Set 3 | oranjemund
# Processing record 6 of Set 3 | illoqqortoormiut
# City not found, skipping... illoqqortoormiut
# Processing record 7 of Set 3 | westminster
# Processing record 8 of Set 3 | atar
# Processing record 9 of Set 3 | severo-kurilsk
# Processing record 10 of Set 3 | queanbeyan
# Processing record 11 of Set 3 | carnarvon
# Processing record 12 of Set 3 | busselton
# Processing record 13 of Set 3 | ambulu
# Processing record 14 of Set 3 | hermanus
# Processing record 15 of Set 3 | martapura
# Processing record 16 of Set 3 | zhigansk
# Processing record 17 of Set 3 | coquimbo
# Processing record 18 of Set 3 | mezhdurechensk
# Processing record 19 of Set 3 | lata
# Processing record 20 of Set 3 | vila franca do campo
# Processing record 21 of Set 3 | dauphin
# Processing record 22 of Set 3 | sinkat
# City not found, skipping... sinkat
# Processing record 23 of Set 3 | bargal
# City not found, skipping... bargal
# Processing record 24 of Set 3 | mount gambier
# Processing record 25 of Set 3 | knokke-heist
# Processing record 26 of Set 3 | conceicao do araguaia
# Processing record 27 of Set 3 | sur
# Processing record 28 of Set 3 | shingu
# Processing record 29 of Set 3 | alofi
# Processing record 30 of Set 3 | bandarbeyla
# Processing record 31 of Set 3 | chuy
# Processing record 32 of Set 3 | guerrero negro
# Processing record 33 of Set 3 | yeppoon
# Processing record 34 of Set 3 | dzerzhinsk
# Processing record 35 of Set 3 | felidhoo
# City not found, skipping... felidhoo
# Processing record 36 of Set 3 | the pas
# Processing record 37 of Set 3 | ilulissat
# Processing record 38 of Set 3 | yatou
# Processing record 39 of Set 3 | aklavik
# Processing record 40 of Set 3 | sheltozero
# Processing record 41 of Set 3 | bengkulu
# Processing record 42 of Set 3 | bubaque
# Processing record 43 of Set 3 | cape town
# Processing record 44 of Set 3 | clinton
# Processing record 45 of Set 3 | solnechnyy
# Processing record 46 of Set 3 | esperance
# Processing record 47 of Set 3 | solwezi
# Processing record 48 of Set 3 | dongying
# Processing record 49 of Set 3 | ponta do sol
# Processing record 50 of Set 3 | srednekolymsk
# Processing record 1 of Set 4 | akhtubinsk
# Processing record 2 of Set 4 | san quintin
# Processing record 3 of Set 4 | pineto
# Processing record 4 of Set 4 | chumikan
# Processing record 5 of Set 4 | orlik
# Processing record 6 of Set 4 | taolanaro
# City not found, skipping... taolanaro
# Processing record 7 of Set 4 | moussoro
# Processing record 8 of Set 4 | bairiki
# Processing record 9 of Set 4 | arraial do cabo
# Processing record 10 of Set 4 | barrow
# Processing record 11 of Set 4 | saryshagan
# City not found, skipping... saryshagan
# Processing record 12 of Set 4 | mawlaik
# Processing record 13 of Set 4 | tir pol
# City not found, skipping... tir pol
# Processing record 14 of Set 4 | tumannyy
# City not found, skipping... tumannyy
# Processing record 15 of Set 4 | tuktoyaktuk
# Processing record 16 of Set 4 | bogorodskoye
# Processing record 17 of Set 4 | emilio carranza
# Processing record 18 of Set 4 | mana
# Processing record 19 of Set 4 | juneau
# Processing record 20 of Set 4 | cherskiy
# Processing record 21 of Set 4 | melilla
# Processing record 22 of Set 4 | hambantota
# Processing record 23 of Set 4 | port alfred
# Processing record 24 of Set 4 | thompson
# Processing record 25 of Set 4 | soroti
# Processing record 26 of Set 4 | mys shmidta
# City not found, skipping... mys shmidta
# Processing record 27 of Set 4 | willowmore
# Processing record 28 of Set 4 | bosansko grahovo
# Processing record 29 of Set 4 | isangel
# Processing record 30 of Set 4 | bundaberg
# Processing record 31 of Set 4 | edgewater
# Processing record 32 of Set 4 | skegness
# Processing record 33 of Set 4 | kijang
# Processing record 34 of Set 4 | jabiru
# City not found, skipping... jabiru
# Processing record 35 of Set 4 | dong xoai
# Processing record 36 of Set 4 | saldanha
# Processing record 37 of Set 4 | rocky mount
# Processing record 38 of Set 4 | ballina
# Processing record 39 of Set 4 | mecca
# Processing record 40 of Set 4 | benidorm
# Processing record 41 of Set 4 | saint-louis
# Processing record 42 of Set 4 | saleaula
# City not found, skipping... saleaula
# Processing record 43 of Set 4 | fengzhen
# Processing record 44 of Set 4 | boulder
# Processing record 45 of Set 4 | mayumba
# Processing record 46 of Set 4 | mezen
# Processing record 47 of Set 4 | upernavik
# Processing record 48 of Set 4 | weinan
# Processing record 49 of Set 4 | araouane
# Processing record 50 of Set 4 | xuanzhou
# Processing record 1 of Set 5 | goderich
# Processing record 2 of Set 5 | kutum
# Processing record 3 of Set 5 | elblag
# Processing record 4 of Set 5 | darhan
# Processing record 5 of Set 5 | port-gentil
# Processing record 6 of Set 5 | natal
# Processing record 7 of Set 5 | haines junction
# Processing record 8 of Set 5 | donegal
# Processing record 9 of Set 5 | suluq
# Processing record 10 of Set 5 | faanui
# Processing record 11 of Set 5 | mathbaria
# Processing record 12 of Set 5 | lisa
# Processing record 13 of Set 5 | luderitz
# Processing record 14 of Set 5 | huron
# Processing record 15 of Set 5 | saint-philippe
# Processing record 16 of Set 5 | mayo
# Processing record 17 of Set 5 | sentyabrskiy
# City not found, skipping... sentyabrskiy
# Processing record 18 of Set 5 | yanam
# Processing record 19 of Set 5 | kathu
# Processing record 20 of Set 5 | cidreira
# Processing record 21 of Set 5 | longyearbyen
# Processing record 22 of Set 5 | shimoda
# Processing record 23 of Set 5 | olinda
# Processing record 24 of Set 5 | termiz
# Processing record 25 of Set 5 | alyangula
# Processing record 26 of Set 5 | ponta delgada
# Processing record 27 of Set 5 | sao filipe
# Processing record 28 of Set 5 | coyotepec
# Processing record 29 of Set 5 | san vicente
# Processing record 30 of Set 5 | dargaville
# Processing record 31 of Set 5 | kapit
# Processing record 32 of Set 5 | itarema
# Processing record 33 of Set 5 | lompoc
# Processing record 34 of Set 5 | ribeira grande
# Processing record 35 of Set 5 | amderma
# City not found, skipping... amderma
# Processing record 36 of Set 5 | kamenka
# Processing record 37 of Set 5 | pangnirtung
# Processing record 38 of Set 5 | tuatapere
# Processing record 39 of Set 5 | pisco
# Processing record 40 of Set 5 | labuhan
# Processing record 41 of Set 5 | guanajuato
# Processing record 42 of Set 5 | presidencia roque saenz pena
# Processing record 43 of Set 5 | okha
# Processing record 44 of Set 5 | vostok
# Processing record 45 of Set 5 | poso
# Processing record 46 of Set 5 | hasaki
# Processing record 47 of Set 5 | nguiu
# City not found, skipping... nguiu
# Processing record 48 of Set 5 | mnogovershinnyy
# Processing record 49 of Set 5 | vieques
# Processing record 50 of Set 5 | purpe
# Processing record 1 of Set 6 | hamilton
# Processing record 2 of Set 6 | mataura
# Processing record 3 of Set 6 | pliska
# Processing record 4 of Set 6 | arlit
# Processing record 5 of Set 6 | acapulco
# Processing record 6 of Set 6 | dromolaxia
# Processing record 7 of Set 6 | les cayes
# Processing record 8 of Set 6 | lebu
# Processing record 9 of Set 6 | carbonia
# Processing record 10 of Set 6 | carutapera
# Processing record 11 of Set 6 | rosarito
# Processing record 12 of Set 6 | manta
# Processing record 13 of Set 6 | luanda
# Processing record 14 of Set 6 | radomsko
# Processing record 15 of Set 6 | pampa
# Processing record 16 of Set 6 | klaksvik
# Processing record 17 of Set 6 | taywarah
# Processing record 18 of Set 6 | batagay-alyta
# Processing record 19 of Set 6 | lock haven
# Processing record 20 of Set 6 | lavrentiya
# Processing record 21 of Set 6 | ixtapa
# Processing record 22 of Set 6 | skagastrond
# City not found, skipping... skagastrond
# Processing record 23 of Set 6 | klyuchi
# Processing record 24 of Set 6 | angoche
# Processing record 25 of Set 6 | nhulunbuy
# Processing record 26 of Set 6 | nikolskoye
# Processing record 27 of Set 6 | shache
# Processing record 28 of Set 6 | aflu
# City not found, skipping... aflu
# Processing record 29 of Set 6 | diamantino
# Processing record 30 of Set 6 | saint george
# Processing record 31 of Set 6 | bras-panon
# Processing record 32 of Set 6 | muroto
# Processing record 33 of Set 6 | takoradi
# Processing record 34 of Set 6 | angoram
# Processing record 35 of Set 6 | kruisfontein
# Processing record 36 of Set 6 | mehamn
# Processing record 37 of Set 6 | souillac
# Processing record 38 of Set 6 | sinjah
# City not found, skipping... sinjah
# Processing record 39 of Set 6 | oktyabrskiy
# Processing record 40 of Set 6 | tsihombe
# City not found, skipping... tsihombe
# Processing record 41 of Set 6 | skalistyy
# City not found, skipping... skalistyy
# Processing record 42 of Set 6 | chernyshevskiy
# Processing record 43 of Set 6 | alghero
# Processing record 44 of Set 6 | russell
# Processing record 45 of Set 6 | bogale
# Processing record 46 of Set 6 | istok
# Processing record 47 of Set 6 | preobrazheniye
# Processing record 48 of Set 6 | noumea
# Processing record 49 of Set 6 | marsh harbour
# Processing record 50 of Set 6 | mangochi
# Processing record 1 of Set 7 | kahului
# Processing record 2 of Set 7 | dingle
# Processing record 3 of Set 7 | kapaa
# Processing record 4 of Set 7 | lagos
# Processing record 5 of Set 7 | clyde river
# Processing record 6 of Set 7 | zhanatas
# City not found, skipping... zhanatas
# Processing record 7 of Set 7 | tshane
# Processing record 8 of Set 7 | vila velha
# Processing record 9 of Set 7 | saint-pierre
# Processing record 10 of Set 7 | maxixe
# Processing record 11 of Set 7 | moss vale
# Processing record 12 of Set 7 | qandala
# Processing record 13 of Set 7 | marcona
# City not found, skipping... marcona
# Processing record 14 of Set 7 | safaga
# Processing record 15 of Set 7 | sao joao batista
# Processing record 16 of Set 7 | hami
# Processing record 17 of Set 7 | bowen
# Processing record 18 of Set 7 | barranca
# Processing record 19 of Set 7 | kavaratti
# Processing record 20 of Set 7 | baykit
# Processing record 21 of Set 7 | jaciara
# Processing record 22 of Set 7 | callaguip
# Processing record 23 of Set 7 | hidalgotitlan
# Processing record 24 of Set 7 | bela
# Processing record 25 of Set 7 | tabiauea
# City not found, skipping... tabiauea
# Processing record 26 of Set 7 | nouadhibou
# Processing record 27 of Set 7 | teplyk
# Processing record 28 of Set 7 | fortuna
# Processing record 29 of Set 7 | half moon bay
# Processing record 30 of Set 7 | matara
# Processing record 31 of Set 7 | madingou
# Processing record 32 of Set 7 | turbat
# Processing record 33 of Set 7 | poum
# Processing record 34 of Set 7 | soeng sang
# Processing record 35 of Set 7 | itoman
# Processing record 36 of Set 7 | arcata
# Processing record 37 of Set 7 | leningradskiy
# Processing record 38 of Set 7 | pagudpud
# Processing record 39 of Set 7 | seoul
# Processing record 40 of Set 7 | naryan-mar
# Processing record 41 of Set 7 | taunton
# Processing record 42 of Set 7 | tiksi
# Processing record 43 of Set 7 | san fernando
# Processing record 44 of Set 7 | port lincoln
# Processing record 45 of Set 7 | yumbe
# Processing record 46 of Set 7 | djibo
# Processing record 47 of Set 7 | zwedru
# Processing record 48 of Set 7 | rio gallegos
# Processing record 49 of Set 7 | lakes entrance
# Processing record 50 of Set 7 | acari
# Processing record 1 of Set 8 | olafsvik
# Processing record 2 of Set 8 | horconcitos
# Processing record 3 of Set 8 | banjar
# Processing record 4 of Set 8 | manzhouli
# Processing record 5 of Set 8 | verkhnyaya toyma
# Processing record 6 of Set 8 | bella union
# Processing record 7 of Set 8 | nizhneyansk
# City not found, skipping... nizhneyansk
# Processing record 8 of Set 8 | vallenar
# Processing record 9 of Set 8 | jieshi
# Processing record 10 of Set 8 | taltal
# Processing record 11 of Set 8 | erzincan
# Processing record 12 of Set 8 | hofn
# Processing record 13 of Set 8 | bolungarvik
# City not found, skipping... bolungarvik
# Processing record 14 of Set 8 | nueva gerona
# Processing record 15 of Set 8 | tuy hoa
# Processing record 16 of Set 8 | marrakesh
# Processing record 17 of Set 8 | gawan
# Processing record 18 of Set 8 | grindavik
# Processing record 19 of Set 8 | georgetown
# Processing record 20 of Set 8 | huntington
# Processing record 21 of Set 8 | portree
# Processing record 22 of Set 8 | belushya guba
# City not found, skipping... belushya guba
# Processing record 23 of Set 8 | vardo
# Processing record 24 of Set 8 | port hedland
# Processing record 25 of Set 8 | kirksville
# Processing record 26 of Set 8 | stepnyak
# Processing record 27 of Set 8 | lagoa
# Processing record 28 of Set 8 | nuuk
# Processing record 29 of Set 8 | bilma
# Processing record 30 of Set 8 | mandalgovi
# Processing record 31 of Set 8 | port blair
# Processing record 32 of Set 8 | salalah
# Processing record 33 of Set 8 | auki
# Processing record 34 of Set 8 | mackay
# Processing record 35 of Set 8 | codrington
# Processing record 36 of Set 8 | podporozhye
# Processing record 37 of Set 8 | borba
# Processing record 38 of Set 8 | pitimbu
# Processing record 39 of Set 8 | pacifica
# Processing record 40 of Set 8 | ganzhou
# Processing record 41 of Set 8 | adamas
# Processing record 42 of Set 8 | havre-saint-pierre
# Processing record 43 of Set 8 | ruatoria
# City not found, skipping... ruatoria
# Processing record 44 of Set 8 | yangambi
# Processing record 45 of Set 8 | sheridan
# Processing record 46 of Set 8 | faya
# Processing record 47 of Set 8 | castro
# Processing record 48 of Set 8 | kirakira
# Processing record 49 of Set 8 | jackson
# Processing record 50 of Set 8 | zhangye
# Processing record 1 of Set 9 | venice
# Processing record 2 of Set 9 | ulladulla
# Processing record 3 of Set 9 | asau
# Processing record 4 of Set 9 | cimarron hills
# Processing record 5 of Set 9 | derzhavinsk
# Processing record 6 of Set 9 | great yarmouth
# Processing record 7 of Set 9 | comodoro rivadavia
# Processing record 8 of Set 9 | lorengau
# Processing record 9 of Set 9 | azare
# Processing record 10 of Set 9 | whitehorse
# Processing record 11 of Set 9 | provideniya
# Processing record 12 of Set 9 | lyubech
# Processing record 13 of Set 9 | lundazi
# Processing record 14 of Set 9 | constitucion
# Processing record 15 of Set 9 | dolbeau
# City not found, skipping... dolbeau
# Processing record 16 of Set 9 | moranbah
# Processing record 17 of Set 9 | nanortalik
# Processing record 18 of Set 9 | piacabucu
# Processing record 19 of Set 9 | torbay
# Processing record 20 of Set 9 | ikom
# Processing record 21 of Set 9 | lima
# Processing record 22 of Set 9 | beringovskiy
# Processing record 23 of Set 9 | kenora
# Processing record 24 of Set 9 | benghazi
# Processing record 25 of Set 9 | nome
# Processing record 26 of Set 9 | senno
# Processing record 27 of Set 9 | basco
# Processing record 28 of Set 9 | omsukchan
# Processing record 29 of Set 9 | husavik
# Processing record 30 of Set 9 | chifeng
# Processing record 31 of Set 9 | balikpapan
# Processing record 32 of Set 9 | portland
# Processing record 33 of Set 9 | skagen
# Processing record 34 of Set 9 | omboue
# Processing record 35 of Set 9 | paombong
# Processing record 36 of Set 9 | kez
# Processing record 37 of Set 9 | waingapu
# Processing record 38 of Set 9 | wodonga
# Processing record 39 of Set 9 | benguela
# Processing record 40 of Set 9 | ouadda
# Processing record 41 of Set 9 | amarillo
# Processing record 42 of Set 9 | robertsport
# Processing record 43 of Set 9 | ontario
# Processing record 44 of Set 9 | botro
# Processing record 45 of Set 9 | galle
# Processing record 46 of Set 9 | grand gaube
# Processing record 47 of Set 9 | pampierstad
# Processing record 48 of Set 9 | ustka
# Processing record 49 of Set 9 | harigue
# City not found, skipping... harigue
# Processing record 50 of Set 9 | plettenberg bay
# Processing record 1 of Set 10 | kismayo
# Processing record 2 of Set 10 | ambovombe
# Processing record 3 of Set 10 | himora
# City not found, skipping... himora
# Processing record 4 of Set 10 | balabac
# Processing record 5 of Set 10 | chicama
# Processing record 6 of Set 10 | marsa matruh
# Processing record 7 of Set 10 | fayaoue
# Processing record 8 of Set 10 | miyako
# Processing record 9 of Set 10 | filadelfia
# Processing record 10 of Set 10 | krasnozavodsk
# Processing record 11 of Set 10 | kaeo
# Processing record 12 of Set 10 | buraydah
# Processing record 13 of Set 10 | chakulia
# Processing record 14 of Set 10 | katherine
# Processing record 15 of Set 10 | belaya gora
# Processing record 16 of Set 10 | yarada
# Processing record 17 of Set 10 | pacific grove
# Processing record 18 of Set 10 | harbour breton
# Processing record 19 of Set 10 | gotsu
# Processing record 20 of Set 10 | sorland
# Processing record 21 of Set 10 | tautira
# Processing record 22 of Set 10 | sokoni
# Processing record 23 of Set 10 | mullaitivu
# City not found, skipping... mullaitivu
# Processing record 24 of Set 10 | svetlyy
# Processing record 25 of Set 10 | el dorado
# Processing record 26 of Set 10 | gonaives
# Processing record 27 of Set 10 | pevek
# Processing record 28 of Set 10 | edd
# Processing record 29 of Set 10 | pangai
# Processing record 30 of Set 10 | maningrida
# Processing record 31 of Set 10 | porto novo
# Processing record 32 of Set 10 | kadi
# Processing record 33 of Set 10 | san ramon
# Processing record 34 of Set 10 | lodwar
# Processing record 35 of Set 10 | darnah
# Processing record 36 of Set 10 | ostrovnoy
# Processing record 37 of Set 10 | cairns
# Processing record 38 of Set 10 | tiznit
# Processing record 39 of Set 10 | tubruq
# City not found, skipping... tubruq
# Processing record 40 of Set 10 | sarangani
# Processing record 41 of Set 10 | sola
# Processing record 42 of Set 10 | dubno
# Processing record 43 of Set 10 | khovu-aksy
# Processing record 44 of Set 10 | azrow
# City not found, skipping... azrow
# Processing record 45 of Set 10 | canandaigua
# Processing record 46 of Set 10 | olovyannaya
# Processing record 47 of Set 10 | goya
# Processing record 48 of Set 10 | longlac
# City not found, skipping... longlac
# Processing record 49 of Set 10 | jasper
# Processing record 50 of Set 10 | lolua
# City not found, skipping... lolua
# Processing record 1 of Set 11 | salmas
# Processing record 2 of Set 11 | buchanan
# Processing record 3 of Set 11 | la asuncion
# Processing record 4 of Set 11 | kidal
# Processing record 5 of Set 11 | guiratinga
# Processing record 6 of Set 11 | urucara
# Processing record 7 of Set 11 | waddan
# Processing record 8 of Set 11 | madras
# Processing record 9 of Set 11 | dukat
# Processing record 10 of Set 11 | talnakh
# Processing record 11 of Set 11 | mahon
# Processing record 12 of Set 11 | okato
# Processing record 13 of Set 11 | manggar
# Processing record 14 of Set 11 | hounde
# Processing record 15 of Set 11 | kegayli
# City not found, skipping... kegayli
# Processing record 16 of Set 11 | sompeta
# Processing record 17 of Set 11 | spokane
# Processing record 18 of Set 11 | caibarien
# Processing record 19 of Set 11 | deputatskiy
# Processing record 20 of Set 11 | ambon
# Processing record 21 of Set 11 | uchkent
# Processing record 22 of Set 11 | itum-kale
# Processing record 23 of Set 11 | vila do maio
# Processing record 24 of Set 11 | henties bay
# Processing record 25 of Set 11 | paucartambo
# City not found, skipping... paucartambo
# Processing record 26 of Set 11 | karamea
# City not found, skipping... karamea
# Processing record 27 of Set 11 | dunedin
# Processing record 28 of Set 11 | las varas
# Processing record 29 of Set 11 | tecoanapa
# Processing record 30 of Set 11 | hidalgo
# Processing record 31 of Set 11 | straumen
# Processing record 32 of Set 11 | hadejia
# Processing record 33 of Set 11 | ankazoabo
# Processing record 34 of Set 11 | topolobampo
# Processing record 35 of Set 11 | hay river
# Processing record 36 of Set 11 | nicoya
# Processing record 37 of Set 11 | cedar city
# Processing record 38 of Set 11 | sitka
# Processing record 39 of Set 11 | tazmalt
# Processing record 40 of Set 11 | koslan
# Processing record 41 of Set 11 | tulum
# Processing record 42 of Set 11 | vestmanna
# Processing record 43 of Set 11 | mineiros
# Processing record 44 of Set 11 | inderborskiy
# City not found, skipping... inderborskiy
# Processing record 45 of Set 11 | galveston
# Processing record 46 of Set 11 | aksaray
# Processing record 47 of Set 11 | burica
# City not found, skipping... burica
# Processing record 48 of Set 11 | cermik
# Processing record 49 of Set 11 | salina
# Processing record 50 of Set 11 | murray bridge
# Processing record 1 of Set 12 | amboise
# Processing record 2 of Set 12 | berlevag
# Processing record 3 of Set 12 | dianopolis
# City not found, skipping... dianopolis
# Processing record 4 of Set 12 | tombouctou
# Processing record 5 of Set 12 | saint-leu
# Processing record 6 of Set 12 | placerville
# Processing record 7 of Set 12 | imeni poliny osipenko
# Processing record 8 of Set 12 | port hawkesbury
# Processing record 9 of Set 12 | margate
# Processing record 10 of Set 12 | padang
# Processing record 11 of Set 12 | maceio
# Processing record 12 of Set 12 | yar-sale
# Processing record 13 of Set 12 | manaure
# Processing record 14 of Set 12 | kathmandu
# Processing record 15 of Set 12 | baracoa
# Processing record 16 of Set 12 | vaitape
# Processing record 17 of Set 12 | uddevalla
# Processing record 18 of Set 12 | havelock
# Processing record 19 of Set 12 | athabasca
# Processing record 20 of Set 12 | thai binh
# Processing record 21 of Set 12 | hauterive
# Processing record 22 of Set 12 | christchurch
# Processing record 23 of Set 12 | flinders
# Processing record 24 of Set 12 | bartica
# Processing record 25 of Set 12 | tharrawaddy
# City not found, skipping... tharrawaddy
# Processing record 26 of Set 12 | sibolga
# Processing record 27 of Set 12 | mbuji-mayi
# Processing record 28 of Set 12 | karaul
# City not found, skipping... karaul
# Processing record 29 of Set 12 | george
# Processing record 30 of Set 12 | buritizeiro
# Processing record 31 of Set 12 | sobolevo
# Processing record 32 of Set 12 | port hardy
# Processing record 33 of Set 12 | lazarev
# Processing record 34 of Set 12 | bolshaya murta
# City not found, skipping... bolshaya murta
# Processing record 35 of Set 12 | brufut
# Processing record 36 of Set 12 | helena
# Processing record 37 of Set 12 | pontianak
# Processing record 38 of Set 12 | kichera
# Processing record 39 of Set 12 | karratha
# Processing record 40 of Set 12 | tottori
# Processing record 41 of Set 12 | popondetta
# Processing record 42 of Set 12 | petauke
# Processing record 43 of Set 12 | cumaribo
# City not found, skipping... cumaribo
# Processing record 44 of Set 12 | kalanguy
# Processing record 45 of Set 12 | port macquarie
# Processing record 46 of Set 12 | lipany
# Processing record 47 of Set 12 | riyadh
# Processing record 48 of Set 12 | cayenne
# Processing record 49 of Set 12 | meadow lake
# Processing record 50 of Set 12 | boa vista
# Processing record 1 of Set 13 | salta
# Processing record 2 of Set 13 | kostomuksha
# Processing record 3 of Set 13 | ciudad bolivar
# Processing record 4 of Set 13 | shkotovo-22
# City not found, skipping... shkotovo-22
# Processing record 5 of Set 13 | mandera
# Processing record 6 of Set 13 | odweyne
# Processing record 7 of Set 13 | inongo
# Processing record 8 of Set 13 | denpasar
# Processing record 9 of Set 13 | cabra
# Processing record 10 of Set 13 | marathon
# Processing record 11 of Set 13 | qeshm
# Processing record 12 of Set 13 | cabedelo
# Processing record 13 of Set 13 | agua dulce
# Processing record 14 of Set 13 | hokitika
# Processing record 15 of Set 13 | terenga
# City not found, skipping... terenga
# Processing record 16 of Set 13 | mozhga
# Processing record 17 of Set 13 | grand centre
# City not found, skipping... grand centre
# Processing record 18 of Set 13 | langsa
# Processing record 19 of Set 13 | palabuhanratu
# City not found, skipping... palabuhanratu
# Processing record 20 of Set 13 | san policarpo
# Processing record 21 of Set 13 | sierpc
# Processing record 22 of Set 13 | bastia
# Processing record 23 of Set 13 | voyvozh
# Processing record 24 of Set 13 | pokhara
# Processing record 25 of Set 13 | vysha
# Processing record 26 of Set 13 | ekhabi
# Processing record 27 of Set 13 | malinovoye ozero
# Processing record 28 of Set 13 | avera
# Processing record 29 of Set 13 | mosetse
# Processing record 30 of Set 13 | kamenskoye
# City not found, skipping... kamenskoye
# Processing record 31 of Set 13 | ust-nera
# Processing record 32 of Set 13 | cockburn town
# Processing record 33 of Set 13 | bria
# Processing record 34 of Set 13 | dongsheng
# Processing record 35 of Set 13 | hit
# Processing record 36 of Set 13 | zyryanka
# Processing record 37 of Set 13 | jinka
# Processing record 38 of Set 13 | kati
# Processing record 39 of Set 13 | ucluelet
# Processing record 40 of Set 13 | tawau
# Processing record 41 of Set 13 | quelimane
# Processing record 42 of Set 13 | sile
# Processing record 43 of Set 13 | halvad
# Processing record 44 of Set 13 | apac
# Processing record 45 of Set 13 | new london
# Processing record 46 of Set 13 | razdolinsk
# Processing record 47 of Set 13 | tagusao
# Processing record 48 of Set 13 | tomatlan
# Processing record 49 of Set 13 | mildura
# Processing record 50 of Set 13 | laguna
# Processing record 1 of Set 14 | rivadavia
# Processing record 2 of Set 14 | san pedro
# Processing record 3 of Set 14 | la massana
# Processing record 4 of Set 14 | akalgarh
# Processing record 5 of Set 14 | lensk
# Processing record 6 of Set 14 | nirgua
# Processing record 7 of Set 14 | dongli
# Processing record 8 of Set 14 | pontes e lacerda
# Processing record 9 of Set 14 | khorixas
# Processing record 10 of Set 14 | buluang
# Processing record 11 of Set 14 | xixiang
# Processing record 12 of Set 14 | chornukhy
# Processing record 13 of Set 14 | lasa
# Processing record 14 of Set 14 | pouebo
# Processing record 15 of Set 14 | ambilobe
# Processing record 16 of Set 14 | puqi
# Processing record 17 of Set 14 | maragogi
# Processing record 18 of Set 14 | fare
# Processing record 19 of Set 14 | satitoa
# City not found, skipping... satitoa
# Processing record 20 of Set 14 | kannangad
# Processing record 21 of Set 14 | khorramshahr
# Processing record 22 of Set 14 | praia da vitoria
# Processing record 23 of Set 14 | turukhansk
# Processing record 24 of Set 14 | teya
# Processing record 25 of Set 14 | vangaindrano
# Processing record 26 of Set 14 | scottsboro
# Processing record 27 of Set 14 | zhangjiakou
# Processing record 28 of Set 14 | del rio
# Processing record 29 of Set 14 | fort saint john
# City not found, skipping... fort saint john
# Processing record 30 of Set 14 | vuktyl
# Processing record 31 of Set 14 | opuwo
# Processing record 32 of Set 14 | saint-georges
# Processing record 33 of Set 14 | bac lieu
# Processing record 34 of Set 14 | rolim de moura
# City not found, skipping... rolim de moura
# Processing record 35 of Set 14 | gandiaye
# Processing record 36 of Set 14 | umzimvubu
# City not found, skipping... umzimvubu
# Processing record 37 of Set 14 | providencia
# Processing record 38 of Set 14 | ahuimanu
# Processing record 39 of Set 14 | quatre cocos
# Processing record 40 of Set 14 | irtyshskiy
# Processing record 41 of Set 14 | utiroa
# City not found, skipping... utiroa
# Processing record 42 of Set 14 | boende
# Processing record 43 of Set 14 | actopan
# Processing record 44 of Set 14 | ngaoundere
# Processing record 45 of Set 14 | pimenteiras
# Processing record 46 of Set 14 | mareeba
# Processing record 47 of Set 14 | kapuskasing
# Processing record 48 of Set 14 | coruripe
# Processing record 49 of Set 14 | santa eulalia del rio
# City not found, skipping... santa eulalia del rio
# Processing record 50 of Set 14 | yulara
# Processing record 1 of Set 15 | manado
# Processing record 2 of Set 15 | umm durman
# City not found, skipping... umm durman
# Processing record 3 of Set 15 | twin falls
# Processing record 4 of Set 15 | cayeli
# Processing record 5 of Set 15 | kununurra
# Processing record 6 of Set 15 | dalvik
# Processing record 7 of Set 15 | shanghai
# Processing record 8 of Set 15 | mpika
# Processing record 9 of Set 15 | nokaneng
# Processing record 10 of Set 15 | palmer
# Processing record 11 of Set 15 | higashine
# Processing record 12 of Set 15 | brae
# Processing record 13 of Set 15 | san patricio
# Processing record 14 of Set 15 | abha
# Processing record 15 of Set 15 | narrabri
# Processing record 16 of Set 15 | belmonte
# Processing record 17 of Set 15 | misratah
# Processing record 18 of Set 15 | barcelos
# Processing record 19 of Set 15 | bayshore gardens
# Processing record 20 of Set 15 | bathsheba
# Processing record 21 of Set 15 | broome
# Processing record 22 of Set 15 | kedrovyy
# Processing record 23 of Set 15 | ngunguru
# Processing record 24 of Set 15 | kawana waters
# City not found, skipping... kawana waters
# Processing record 25 of Set 15 | kabalo
# Processing record 26 of Set 15 | pershotravneve
# Processing record 27 of Set 15 | veraval
# Processing record 28 of Set 15 | shaartuz
# City not found, skipping... shaartuz
# Processing record 29 of Set 15 | kotri
# Processing record 30 of Set 15 | sorvag
# City not found, skipping... sorvag
# Processing record 31 of Set 15 | lluta
# Processing record 32 of Set 15 | hohhot
# Processing record 33 of Set 15 | birin
# Processing record 34 of Set 15 | mannarakkat
# Processing record 35 of Set 15 | biskamzha
# Processing record 36 of Set 15 | tank
# Processing record 37 of Set 15 | ixcatepec
# Processing record 38 of Set 15 | homa bay
# Processing record 39 of Set 15 | mount isa
# Processing record 40 of Set 15 | anori
# Processing record 41 of Set 15 | pichayevo
# Processing record 42 of Set 15 | amahai
# Processing record 43 of Set 15 | xining
# Processing record 44 of Set 15 | ketchikan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Converting the array of dictionaries into a pandas dataframe
city_data_df = pd.DataFrame(city_data)

city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Ushuaia      AR -54.8000  -68.3000     26.26        74           0
# 1  Namatanai      PG  -3.6667  152.4333     82.71        75          95
# 2  Saskylakh      RU  71.9167  114.0833     61.50        41          89
# 3   Khatanga      RU  71.9667  102.5000     43.23        88         100
# 4    Tisovec      SK  48.6774   19.9436     49.87        86          20
#
#    Wind Speed Current Description
# 0        5.75           clear sky
# 1       11.43       moderate rain
# 2       10.42     overcast clouds
# 3       14.05       moderate rain
# 4        4.88          few clouds

# %%
# Exporting the data to a csv file
# Creating the csv file
output_data_file = "WeatherPy_Database.csv"

# Exporting that data to the file
city_data_df.to_csv(output_data_file, index_label = "City_ID")
